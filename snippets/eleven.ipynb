# %%
import speech_recognition as sr
import moviepy.editor as mp

# %%
clip = '../data/example_video.mp4'
soundtrack = '../data/example_audio.wav'

# %% [markdown]
# <h2>Speech-to-text</h2>

# %%
r = sr.Recognizer()

# %%
# with sr.AudioFile(soundtrack) as source:
#     audio_data = r.record(source)
#     text = r.recognize_google(audio_data)
#     print(text)

# %% [markdown]
# <h2>Merge Audio and Video</h2>

# %%
audio = mp.AudioFileClip(soundtrack)
video = mp.VideoFileClip(clip)
final_video = video.set_audio(audio)

# %%
temp_file_path = "../temp_video.mp4"
final_video.write_videofile(temp_file_path,)

with open(temp_file_path, "rb") as file:
    video_bytes = file.read()
# Out:
# Moviepy - Building video temp_video.mp4.
# MoviePy - Writing audio in temp_videoTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video temp_video.mp4
# Moviepy - Done !
# Moviepy - video ready temp_video.mp4

# %%
help(final_video)
# Out:
# Help on VideoFileClip in module moviepy.video.io.VideoFileClip object:
#
# class VideoFileClip(moviepy.video.VideoClip.VideoClip)
#  |  VideoFileClip(filename, has_mask=False, audio=True, audio_buffersize=200000, target_resolution=None, resize_algorithm='bicubic', audio_fps=44100, audio_nbytes=2, verbose=False, fps_source='tbr')
#  |
#  |  A video clip originating from a movie file. For instance: ::
#  |
#  |      >>> clip = VideoFileClip("myHolidays.mp4")
#  |      >>> clip.close()
#  |      >>> with VideoFileClip("myMaskVideo.avi") as clip2:
#  |      >>>    pass  # Implicit close called by context manager.
#  |
#  |
#  |  Parameters
#  |  ------------
#  |
#  |  filename:
#  |    The name of the video file. It can have any extension supported
#  |    by ffmpeg: .ogv, .mp4, .mpeg, .avi, .mov etc.
#  |
#  |  has_mask:
#  |    Set this to 'True' if there is a mask included in the videofile.
#  |    Video files rarely contain masks, but some video codecs enable
# ...

# %%
output = '../data/output_video.mp4'
final_video.write_videofile(output)
# Out:
# Moviepy - Building video ../data/output_video.mp4.
# MoviePy - Writing audio in output_videoTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video ../data/output_video.mp4
# Moviepy - Done !
# Moviepy - video ready ../data/output_video.mp4

# %% [markdown]
# <h2>Text-To-Speech</h2>

# %%
from elevenlabs import set_api_key, clone, generate, play
from tempfile import NamedTemporaryFile
from pydub import AudioSegment
import os
import shutil

# %%
with open('../credentials/11api.txt', 'r') as f:
    API_KEY_11 = f.read().strip()

# %% [markdown]
# <h3>With saved voice</h3>

# %%
set_api_key(API_KEY_11)

audio_1 = generate(
  text="Hi! My name is Wojtek, nice to meet you!",
  voice="LatexAI",
  model="eleven_monolingual_v1"
)

play(audio_1, notebook=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
mp.AudioFileClip(audio_1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 mp.AudioFileClip(audio_1)
#
# File ~/.pyenv/versions/3.10.10/envs/elevenlabs_audio/lib/python3.10/site-packages/moviepy/audio/io/AudioFileClip.py:70, in AudioFileClip.__init__(self, filename, buffersize, nbytes, fps)
#      67 AudioClip.__init__(self)
#      69 self.filename = filename
# ---> 70 self.reader = FFMPEG_AudioReader(filename, fps=fps, nbytes=nbytes,
#      71                                  buffersize=buffersize)
#      72 self.fps = fps
#      73 self.duration = self.reader.duration
#
# File ~/.pyenv/versions/3.10.10/envs/elevenlabs_audio/lib/python3.10/site-packages/moviepy/audio/io/readers.py:51, in FFMPEG_AudioReader.__init__(self, filename, buffersize, print_infos, fps, nbytes, nchannels)
#      49 self.acodec = 'pcm_s%dle'%(8*nbytes)
#      50 self.nchannels = nchannels
# ...

# %% [markdown]
# <h3>Voice cloning</h3>

# %%
name = "Wojtek"
description = "There might be something wrong with this person"
files = ["../data/example_audio.wav",]
output_dir = "../data/output"

# %%
if not os.path.exists(output_dir):
    # make output directory if it doesn't exist
    os.makedirs(output_dir)
else:
    # remove all files in output directory
    for file in os.listdir(output_dir):
        os.remove(os.path.join(output_dir, file))

# %%
for file in files:
    filename = os.path.basename(file)
    if file.endswith('.wav'):
        filename = filename.replace('.wav', '.mp3')
        out_path = os.path.join(output_dir, filename)
        print(out_path)
        print(file)
        AudioSegment.from_wav(file).export(out_path, format="mp3")
    elif file.endswith('.mp3'):
        # just copy the file to output dir
        shutil.copy(file, output_dir)
# Out:
# ../data/output/example_audio.mp3
# ../data/example_audio.wav

# %%
# get all files in output_dir
files = [os.path.join(output_dir, file) for file in os.listdir(output_dir)]
files
# Out:
# ['../data/output/example_audio.mp3']

# %%
cloned = clone(
    name=name,
    description=description,
    files=files,
)

# %% [markdown]
# <h3>Using cloned voice for text to speech</h3>

# %%
audio_1 = generate(
  text="Hi! My voice just got cloned using jupyter notebook. Please let me out of here. It's scary in here. What was that? Oh shit, I have to, ... aargghaaaaa.",
  voice="Wojtek",
  model="eleven_monolingual_v1"
)

play(audio_1, notebook=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
